# %%
# -*- coding: utf-8 -*-
"""根据搜索词下载百度图片"""
import re
import sys
import urllib.parse

import requests


def get_onepage_urls(onepageurl):
    """获取单个翻页的所有图片的urls+当前翻页的下一翻页的url"""
    if not onepageurl:
        print('已到最后一页, 结束')
        return [], ''
    try:
        html = requests.get(onepageurl)
        html.encoding = 'utf-8'
        content = html.text
    except Exception as e:
        print(e)
        pic_urls = []
        fanye_url = ''
        return pic_urls, fanye_url
    pic_urls = re.findall('"objURL":"(.*?)",', html, re.S)
    fanye_urls = re.findall(re.compile(r'<a href="(.*)" class="n">下一页</a>'), html, flags=0)
    fanye_url = 'http://image.baidu.com' + fanye_urls[0] if fanye_urls else ''
    return pic_urls, fanye_url


def down_pic(pic_urls):
    """给出图片链接列表, 下载所有图片"""
    for i, pic_url in enumerate(pic_urls):
        try:
            pic = requests.get(pic_url, timeout=15)
            string = str(i + 1) + '.jpg'
            with open(string, 'wb') as f:
                f.write(pic.content)
                print('成功下载第%s张图片: %s' % (str(i + 1), str(pic_url)))
        except Exception as e:
            print('下载第%s张图片时失败: %s' % (str(i + 1), str(pic_url)))
            print(e)
            continue


if __name__ == '__main__':
    keyword = '苍老师'  # 关键词, 改为你想输入的词即可, 相当于在百度图片里搜索一样
    url_init_first = r'http://image.baidu.com/search/flip?tn=baiduimage&ipn=r&ct=201326592&cl=2&lm=-1&st=-1&fm=result&fr=&sf=1&fmq=1497491098685_R&pv=&ic=0&nc=1&z=&se=1&showtab=0&fb=0&width=&height=&face=0&istype=2&ie=utf-8&ctd=1497491098685%5E00_1519X735&word='
    url_init = url_init_first + urllib.parse.quote(keyword, safe='/')
    all_pic_urls = []
    onepage_urls, fanye_url = get_onepage_urls(url_init)
    all_pic_urls.extend(onepage_urls)

    fanye_count = 0  # 累计翻页数
    while 1:
        onepage_urls, fanye_url = get_onepage_urls(fanye_url)
        fanye_count += 1
        # print('第页' % str(fanye_count))
        if fanye_url == '' and onepage_urls == []:
            break
        all_pic_urls.extend(onepage_urls)

    down_pic(list(set(all_pic_urls)))

# %%
# coding=utf-8
"""
爬取百度图片的高清原图
Author          : MirrorMan
Created         : 2017-11-10
"""
import re
import sys
import urllib
import os
 
import requests
 
def get_onepage_urls(onepageurl):
    if not onepageurl:
        print('执行结束')
        return [], ''
    try:
        html = requests.get(onepageurl).text
    except Exception as e:
        print(e)
        pic_urls = []
        fanye_url = ''
        return pic_urls, fanye_url
    pic_urls = re.findall('"objURL":"(.*?)",', html, re.S)
    fanye_urls = re.findall(re.compile(r'<a href="(.*)" class="n">下一页</a>'), html, flags=0)
    fanye_url = 'http://image.baidu.com' + fanye_urls[0] if fanye_urls else ''
    return pic_urls, fanye_url
 
def down_pic(pic_urls,localPath):
    if not os.path.exists(localPath):  # 新建文件夹
        os.mkdir(localPath)
    """给出图片链接列表, 下载图片"""
    for i, pic_url in enumerate(pic_urls):
        try:
            pic = requests.get(pic_url, timeout=15)
            string = str(i + 1) + '.jpg'
            with open(localPath + '%d.jpg' % i, 'wb')as f:
                f.write(pic.content)
          #  with open(string, 'wb') as f:
          #      f.write(pic.content)
                print('成功下载第%s张图片: %s' % (str(i + 1), str(pic_url)))
        except Exception as e:
            print('下载第%s张图片时失败: %s' % (str(i + 1), str(pic_url)))
            print(e)
            continue
 
 
if __name__ == '__main__':
    keyword = '泰勒斯威夫特1920*1080'  # 关键词, 改为你想输入的词即可
    url_init_first = r'http://image.baidu.com/search/flip?tn=baiduimage&ipn=r&ct=201326592&cl=2&lm=-1&st=-1&fm=result&fr=&sf=1&fmq=1497491098685_R&pv=&ic=0&nc=1&z=&se=1&showtab=0&fb=0&width=&height=&face=0&istype=2&ie=utf-8&ctd=1497491098685%5E00_1519X735&word='
    url_init = url_init_first + urllib.parse.quote(keyword, safe='/')
    all_pic_urls = []
    onepage_urls, fanye_url = get_onepage_urls(url_init)
    all_pic_urls.extend(onepage_urls)
 
    fanye_count = 1  # 图片所在页数，下载完后调整这里就行
    while 1:
        onepage_urls, fanye_url = get_onepage_urls(fanye_url)
        fanye_count += 1
        print('第%s页' % fanye_count)
        if fanye_url == '' and onepage_urls == []:
            break
        all_pic_urls.extend(onepage_urls)
 
    down_pic(list(set(all_pic_urls)),r'F:\anacondapython\reptile')#保存位置也可以修改
# Out:
# 执行结束
# 第2页
# 成功下载第1张图片: http://images4.fanpop.com/image/photos/18800000/Lovley-Taylor-Wallpaper-taylor-swift-18881231-1920-1080.jpg
# 成功下载第2张图片: http://images4.fanpop.com/image/photos/21500000/Taylor-Swift-Mine-Music-Video-taylor-swift-21520002-1920-1080.jpg
# 成功下载第3张图片: http://img2.fengniao.com/g1/M00/05/11/Cg-4rFZC-2uIAZXeAAdr8QGV4MAAANYFQHgKoUAB2wJ826.jpg
# 成功下载第4张图片: http://images4.fanpop.com/image/photos/21500000/Taylor-Swift-Mine-Music-Video-taylor-swift-21519823-1920-1080.jpg
# 成功下载第5张图片: http://pic1.win4000.com/pic/f/12/6cdc1426706.jpg
# 成功下载第6张图片: http://images4.fanpop.com/image/photos/21500000/Taylor-Swift-Mine-Music-Video-taylor-swift-21519794-1920-1080.jpg
# 成功下载第7张图片: http://b-ssl.duitang.com/uploads/item/201602/19/20160219234149_Z4UGa.jpeg
# 成功下载第8张图片: http://4444.rfkq.net/attachment/month_1303/13032908563465249d4e92d327.jpg
# 成功下载第9张图片: http://images4.fanpop.com/image/photos/21500000/Taylor-Swift-Mine-Music-Video-taylor-swift-21519996-1920-1080.jpg
# 成功下载第10张图片: http://imgstatic.ctfile.com/upload/portal/12575056/E5C4Qv1W/20170129-1485663300475521.jpg
# 成功下载第11张图片: http://pic1.win4000.com/pic/b/dd/3cdf1426877.jpg
# 下载第12张图片时失败: http://images5.fanpop.com/image/photos/31800000/t-swift-taylor-swift-31852618-1920-1080.jpg
# HTTPConnectionPool(host='images5.fanpop.com', port=80): Max retries exceeded with url: /image/photos/31800000/t-swift-taylor-swift-31852618-1920-1080.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x000